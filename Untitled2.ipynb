# %% [markdown]
# <a href="https://colab.research.google.com/github/ArcasHH/ML/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    # !wget -q -O requirements.txt https://raw.githubusercontent.com/ArcasHH/ML/main/requirements.txt
    # !pip install -q -r requirements.txt

# %%
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/ArcasHH/ML/main/forestfires.csv', 
                      header=None, 
                      names=['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area'])
dataset.sample(10, random_state=0)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH wind rain   area
# 142  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31  4.5    0   0.55
# 107  4  5   mar  thu  91.4   30.7   74.3   7.5  18.2  29  3.1    0      0
# 206  4  5   sep  thu  92.9    137  706.4   9.2  22.1  34  1.8    0  14.57
# 261  2  4   aug  mon  93.6   97.9    542  14.4  28.3  32    4    0   8.85
# 172  8  6   aug  wed  85.6   90.4  609.6   6.6  17.4  50    4    0   2.69
# 15   6  5   sep  wed  92.9  133.3  699.6   9.2  26.4  21  4.5    0      0
# 465  6  4   feb  tue  75.1    4.4   16.2   1.9   5.1  77  5.4    0   2.14
# 229  4  6   sep  sun  93.5  149.3  728.6   8.1  28.3  26  3.1    0   64.1
# 382  8  6   aug  thu  90.7  194.1    643   6.8  16.2  63  2.7    0  16.33
# 97   3  4   feb  sat  83.9      8   30.2   2.6  12.7  48  1.8    0      0

# %%
print('Размер выборки составляет l={} объектов.'.format(len(dataset)))
# Out:
# Размер выборки составляет l=518 объектов.

# %%
block = pd.DataFrame(dataset)
block.pop('day')
block.pop('FFMC')
block.pop('DMC')
block.pop('DC')
block.pop('RH')
block.pop('ISI')
block.pop('rain')
block.pop('X')
block.pop('Y')
print(block)
block.sample(10, random_state=0)
# Out:
#      month  temp  wind   area
# 0    month  temp  wind   area
# 1      mar   8.2   6.7      0
# 2      oct    18   0.9      0
# 3      oct  14.6   1.3      0
# 4      mar   8.3     4      0
# ..     ...   ...   ...    ...
# 513    aug  27.8   2.7   6.44
# 514    aug  21.9   5.8  54.29
# 515    aug  21.2   6.7  11.16
# 516    aug  25.6     4      0
# 517    nov  11.8   4.5      0
#
# [518 rows x 4 columns]
#     month  temp wind   area
# 142   aug  23.3  4.5   0.55
# 107   mar  18.2  3.1      0
# 206   sep  22.1  1.8  14.57
# 261   aug  28.3    4   8.85
# 172   aug  17.4    4   2.69
# 15    sep  26.4  4.5      0
# 465   feb   5.1  5.4   2.14
# 229   sep  28.3  3.1   64.1
# 382   aug  16.2  2.7  16.33
# 97    feb  12.7  1.8      0

# %%
sns.pairplot(block, hue='wind', height=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-b2cf9b56f5fa> in <module>()
# ----> 1 sns.pairplot(block, hue='wind', height=2)
#       2 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                     hue_order=hue_order, palette=palette, corner=corner,
# -> 2098                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2099
#    2100     # Add the markers here as PairGrid has figured out how many levels of the
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1231
#    1232         if not x_vars:
# -> 1233             raise ValueError("No variables found for grid columns.")
#    1234         if not y_vars:
#    1235             raise ValueError("No variables found for grid rows.")
#
# ValueError: No variables found for grid columns.
